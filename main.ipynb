# %% [markdown]
# # **Weight and Fuel Efficiency Correlation in  Commercial Cars from 1970-1982**
#
# The purpose of this investigation is too find a trend between weight of commercial cars
# and better fuel efficiency in a range of years between 1970-1982. We will analyze wether we see a solid positive trend and extract the exact details to fully understand the graph.
#
# The graph below can be divided into three main sections were we can analyze it's behavior. We would divide it in it's x axis, into the following parts: Section One (1970-1974), Section Two (1975-1978), and Section Three (1979-1982).
#
# The average fuel efficiency of this chosen dataset is 23.52 mpg. Similarly, the average weight is 2970.26 lbs. This would be our reference numbers for our measurements.
#
#  An important insight is that based on the distribution of the dataset between this section, we can see how it divides itself into three clusters on the y axis, especially on the years 1972 and 1973. based only on the information we get from the graph, we can tell that the car industry probably divide it's market into three categories: light cars, medium weight cars and heavy cars. We also see that on average most lay on the middle to light section, which tells us that extreme heavy cars were not the norm. However, its important to clarify that the parameters that divide this clusters  will vary from section to section. We will see how in next sections what used to be the heavy section will then be the middle weight section in another section.

# %% [markdown]
# #### **Average Weight and MPG**

# %%
#mean
fuel_average = auto_dataset["mpg"].mean().round(2)
print(" Average Fuel Efficency:", fuel_average, "mpg")

weight_average = auto_dataset["weight"].mean().round(2)
print("Average Weight:", weight_average, "lbs")

# %% [markdown]
# #### **Weight Graph**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

auto_dataset = pd.read_csv("Auto.csv",
                          na_values=['?'])

sample_auto_dataset = pd.DataFrame(auto_dataset)

sample_auto_dataset.loc[lambda df: (df["year"] > 69) & (df["year"] <= 79), ["mpg", "weight"]]

# plotting the sample
plt.figure(figsize=(12,10))
plt.scatter(sample_auto_dataset["year"], sample_auto_dataset["weight"], color="red", label="Weight in pounds (lbs)")
plt.ylabel("WEIGHT")
plt.xlabel("Years")
plt.title("Weight in pounds of comercial cars from 1970-1980")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# #### **Fuel Efficiency Graph**

# %%
sample_auto_dataset.loc[lambda df: (df["year"] > 69) & (df["year"] <= 79), ["mpg", "weight"]]

# plotting the sample
plt.figure(figsize=(12,10))
plt.scatter(sample_auto_dataset["year"], sample_auto_dataset["mpg"], color="blue" ,label = "Miles per Gallon")
plt.ylabel("MPG")
plt.xlabel("Years")
plt.title("MPG efficency in comercial cars from 1970-1980")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# #### **Section 1**

# %% [markdown]
# ##### **Fuel Efficiency Graph section 1**

# %%
section_1 = pd.DataFrame(auto_dataset)

filtered_section_1 = section_1.loc[lambda df: (df["year"] >= 69) & (df["year"] <= 74), ["name", "year", "mpg", "weight"]]

#graph
plt.figure(figsize=(12, 10))
plt.scatter(filtered_section_1["year"], filtered_section_1["mpg"], color="blue", label="Miles per Gallon")
plt.xlabel("Years")
plt.ylabel("MPG (Miles per Gallon)")
plt.title("MPG efficiency between 1970-1974")
plt.legend()
plt.show()

print("Section 1 1970-1974:\n", filtered_section_1, "\n")
# Out:
# Section 1 1970-1974:
#                            name  year   mpg  weight
# 0    chevrolet chevelle malibu    70  18.0    3504
# 1            buick skylark 320    70  15.0    3693
# 2           plymouth satellite    70  18.0    3436
# 3                amc rebel sst    70  16.0    3433
# 4                  ford torino    70  17.0    3449
# ..                         ...   ...   ...     ...
# 147                   fiat 128    74  24.0    2108
# 148                fiat 124 tc    74  26.0    2246
# 149                honda civic    74  24.0    2489
# 150                     subaru    74  26.0    2391
# 151                  fiat x1.9    74  31.0    2000
#
# [152 rows x 4 columns]

# %% [markdown]
# #### **Weight Graph section 1**

# %%
plt.figure(figsize=(12,10))
plt.scatter(filtered_section_1["year"], filtered_section_1["weight"], color="red", label="Pounds(lbs)")
plt.xlabel("Years")
plt.ylabel("Weight")
plt.title("Weight of Cars Between 1970-1974")
plt.legend()
plt.show()

# %% [markdown]
# #### **Average Weight and MPG section 1**

# %%
average_weight_section_1 = filtered_section_1["weight"].mean().round(2)
print("Average weight of section 1:", average_weight_section_1, "lbs")

average_mpg_section_1 = filtered_section_2["mpg"].mean().round(2)
print("Average fuel efficiency of section 1:", average_mpg_section_1, "mpg")
# Out:
# Average weight of section 1: 3202.66 lbs
# Average fuel efficiency of section 1: 22.36 mpg

# %% [markdown]
# #### **Max and Min Value of Section 1**

# %%
max_weight_section_1 = filtered_section_1["weight"].max()
print(f"Maximum weight in section 1: {max_weight_section_1} lbs")

min_weight_section_1 = filtered_section_1["weight"].min()
print(f"Minimum weight in section 1: {min_weight_section_1} lbs")

max_mpg_section_1 = filtered_section_1["mpg"].max()
print(f"Maximum mpg in section 1: {max_mpg_section_1} mpg")

min_mpg_section_1 = filtered_section_1["mpg"].min()
print(f"Minimum mpg in section 1: {min_mpg_section_1} mpg")
# Out:
# Maximum weight in section 1: 5140 lbs
# Minimum weight in section 1: 1613 lbs
# Maximum mpg in section 1: 35.0 mpg
# Minimum mpg in section 1: 9.0 mpg

# %% [markdown]
# #### **Least/Most  Fuel Efficient Car Per Year Section 1**

# %%
import pandas as pd
import numpy as np

# Read the dataset
auto_dataset = pd.read_csv("Auto.csv", na_values=['?'])

# Define the range of years you're interested in
years_1970_1974 = [70, 71, 72, 73, 74]

# Dictionaries to store the least and most efficient cars
least_efficient_cars_1970_1974 = {}
most_efficient_cars_1970_1974 = {}

# Process each year
for year in years_1970_1974:
    cars = auto_dataset.loc[auto_dataset['year'] == year, ["year", "name", "mpg"]]
    least_efficient_cars_1970_1974[year] = cars.loc[cars["mpg"].idxmin()]
    most_efficient_cars_1970_1974[year] = cars.loc[cars["mpg"].idxmax()]

# Print the results
for year in years_1970_1974:
    print(f'The least efficient car in {year + 1900} was {least_efficient_cars_1970_1974[year]["name"]} with mpg of {least_efficient_cars_1970_1974[year]["mpg"]}')
    print(f'The most efficient car in {year + 1900} was {most_efficient_cars_1970_1974[year]["name"]} with mpg of {most_efficient_cars_1970_1974[year]["mpg"]}')
    print("\n")
# Out:
# The least efficient car in 1970 was hi 1200d with mpg of 9.0
# The most efficient car in 1970 was datsun pl510 with mpg of 27.0
#
#
# The least efficient car in 1971 was dodge monaco (sw) with mpg of 12.0
# The most efficient car in 1971 was datsun 1200 with mpg of 35.0
#
#
# The least efficient car in 1972 was mercury marquis with mpg of 11.0
# The most efficient car in 1972 was datsun 510 (sw) with mpg of 28.0
#
#
# The least efficient car in 1973 was chevrolet impala with mpg of 11.0
# The most efficient car in 1973 was fiat 128 with mpg of 29.0
#
#
# The least efficient car in 1974 was buick century luxus (sw) with mpg of 13.0
# The most efficient car in 1974 was toyota corolla 1200 with mpg of 32.0

# %% [markdown]
# #### **Lightest/Heaviest Car Per Year in Section 1**

# %%
lightest_cars_1970_1974 = {}
heaviest_cars_1970_1974 = {}

for year in years_1970_1974:
    cars = auto_dataset.loc[auto_dataset["year"] == year, ["year", "name", "weight"]]
    lightest_cars_1970_1974[year] = cars.loc[cars["weight"].idxmin()]
    heaviest_cars_1970_1974[year] = cars.loc[cars["weight"].idxmax()]

for year in years_1970_1974:
    
    print(f'The lightest car from {year + 1900} was the {lightest_cars_1970_1974[year]["name"]} with a weight of {lightest_cars_1970_1974[year]["weight"]} lbs')
    print(f'The heaviest car from {year + 1900} was the {heaviest_cars_1970_1974[year]["name"]} with a weight of {heaviest_cars_1970_1974[year]["weight"]} lbs')
    print("\n")
# Out:
# The lightest car from 1970 was the volkswagen 1131 deluxe sedan with a weight of 1835 lbs
# The heaviest car from 1970 was the hi 1200d with a weight of 4732 lbs
#
#
# The lightest car from 1971 was the datsun 1200 with a weight of 1613 lbs
# The heaviest car from 1971 was the pontiac safari (sw) with a weight of 5140 lbs
#
#
# The lightest car from 1972 was the toyota corolla 1600 (sw) with a weight of 2100 lbs
# The heaviest car from 1972 was the mercury marquis with a weight of 4633 lbs
#
#
# The lightest car from 1973 was the fiat 128 with a weight of 1867 lbs
# The heaviest car from 1973 was the chevrolet impala with a weight of 4997 lbs
#
#
# The lightest car from 1974 was the toyota corona with a weight of 1649 lbs
# The heaviest car from 1974 was the buick century luxus (sw) with a weight of 4699 lbs

# %% [markdown]
# #### **Analysis Section 1**

# %% [markdown]
# **Weight Analysis**
#
# The most characteristic detail about section one is that we find the heaviest and lightest cars in all of the three sections. The heaviest car is the Pontiac Safari (sw) from 1971 with a weight of 5140 lbs while we also find the lightest car which was the Datsun 1200 with a weight of 1613 lbs also from 1971. Based on this we can conclude that 1971 was the year with the biggest range of weights. Average weight of section 1 is 3202.66 lbs, which is considerably higher than the general average of 2970.26 lbs.
#
# The years with the most peculiar behavior are 1972 and 1973. In the distribution of data from 1972 we see that it's divided into two main groups: one far below the average weight and one far above the average weight. In fact, the ones that are close to the mean are the outliers. We can infer that this year car manufacturers really went for polar directions.
# Meanwhile the distribution of the year 1973 is more diverse as the range is really packed and there's no significant gaps among the data distribution. We see a great variety of below weight average cars as well as in the above average weight cars.
#
# **Fuel Efficiency Analysis**
#
# The least efficient car in section 1 and in all of the dataset was the hi 1200d from 1970 with mpg of 9.0 while the most efficient car of section 1 was the Datsun 1200 from 1971 with an mpg of 32. Once again, 1971 with another statistic. The average fuel efficiency of section 1 is 22.36 mpg.Comparing it to other sections and the fact that the majority of the cars of section 1 are below the average mpg of 23.52 can make us conclude that this were the years with the worst mpg performance of this dataset.
#
# The worst performing year of section 1 and of all of the dataset is 1970. Here we can find the least fuel efficient car and only two cars are above the average mpg. The best performing year was 1974, which also is the year were the graph starts to take a upwards direction. 1971 doesn't take the crown if because I removed it's outlier which visually made it seem as the best performant year.

# %% [markdown]
# #### **Section 2**

# %% [markdown]
# ##### **Fuel Efficiency Graph**

# %%
section_2 = pd.DataFrame(auto_dataset)

filtered_section_2 = section_2.loc[lambda df: (df["year"] >= 75) & (df["year"] <= 78), ["name", "year", "mpg", "weight"]]


plt.figure(figsize=(12,10))
plt.scatter(filtered_section_2["year"], filtered_section_2["mpg"], color="red", label="miles per gallon")
plt.xlabel("years")
plt.ylabel("mpg")
plt.title("MPG efficiency between 1975-1978")
plt.legend()
plt.show()

# %% [markdown]
# #### **Weight Graph**

# %%
plt.figure(figsize=(12,10))
plt.scatter(filtered_section_2["year"], filtered_section_2["weight"], color="blue", label="Pounds (lbs)")
plt.xlabel("Years")
plt.ylabel("Weight")
plt.title("Weight In Cars from 1975-1978")
plt.legend()
plt.show()

# %%
section_2 = pd.DataFrame(auto_dataset)

filtered_section_2 = section_2.loc[lambda df: (df["year"] >= 75) & (df["year"] <= 78), ["name", "year", "mpg", "weight"]]

print("Section 2 1975-1978:\n", filtered_section_2, "\n")
# Out:
# Section 2 1975-1978:
#                          name  year   mpg  weight
# 152  plymouth valiant custom    75  19.0    3264
# 153           chevrolet nova    75  18.0    3459
# 154          mercury monarch    75  15.0    3432
# 155            ford maverick    75  15.0    3158
# 156         pontiac catalina    75  16.0    4668
# ..                       ...   ...   ...     ...
# 275              volvo 264gl    78  17.0    3140
# 276               saab 99gle    78  21.6    2795
# 277            peugeot 604sl    78  16.2    3410
# 278      volkswagen scirocco    78  31.5    1990
# 279          honda accord lx    78  29.5    2135
#
# [128 rows x 4 columns]

# %% [markdown]
# #### **Average Weight and MPG of Section 2**

# %%
average_weight_section_2 = filtered_section_2["weight"].mean().round(2)
print(f"The average weight of section 2 is {average_weight_section_2} lbs")

average_mpg_section_2 = filtered_section_2["mpg"].mean().round(2)
print(f"The average mpg of section 2 is {average_mpg_section_2} mpg")
# Out:
# The average weight of section 2 is 3022.91 lbs
# The average mpg of section 2 is 22.36 mpg

# %% [markdown]
# #### **Least/Most  Fuel Efficient Car Per Year Section 2**

# %%
auto_dataset = pd.read_csv("Auto.csv", na_values=['?'])

years_1975_1978 = [75,76,77,78]

most_efficient_cars_1975_1978 = {}
least_efficient_cars_1975_1978 = {}

for year in years_1975_1978:
    cars = auto_dataset.loc[auto_dataset["year"] == year, ["year", "name", "mpg"]]
    most_efficient_cars_1975_1978[year] = cars.loc[cars["mpg"].idxmax()]
    least_efficient_cars_1975_1978[year] = cars.loc[cars["mpg"].idxmin()]
    
for year in years_1975_1978:
    print(f'The most fuel efficient car from the year {year + 1900} was the {most_efficient_cars_1975_1978[year]["name"]} with a mpg of {most_efficient_cars_1975_1978[year]["mpg"]}')
    print(f'The least fuel efficient car from the year {year + 1900} was the {least_efficient_cars_1975_1978[year]["name"]} with a mpg of {least_efficient_cars_1975_1978[year]["mpg"]}')
    print('\n')
# Out:
# The most fuel efficient car from the year 1975 was the honda civic cvcc with a mpg of 33.0
# The least fuel efficient car from the year 1975 was the ford mustang ii with a mpg of 13.0
#
#
# The most fuel efficient car from the year 1976 was the honda civic with a mpg of 33.0
# The least fuel efficient car from the year 1976 was the plymouth volare premier v8 with a mpg of 13.0
#
#
# The most fuel efficient car from the year 1977 was the renault 5 gtl with a mpg of 36.0
# The least fuel efficient car from the year 1977 was the mercury cougar brougham with a mpg of 15.0
#
#
# The most fuel efficient car from the year 1978 was the volkswagen rabbit custom diesel with a mpg of 43.1
# The least fuel efficient car from the year 1978 was the peugeot 604sl with a mpg of 16.2

# %% [markdown]
# ##### **Lightest/Heaviest Car From Section 2**

# %%
heaviest_cars_1975_1978 = {}
lightest_cars_1975_1978 = {}

for year in years_1975_1978:
    cars = auto_dataset.loc[auto_dataset["year"] == year, ["year", "name", "weight"]]
    lightest_cars_1975_1978[year] = cars.loc[cars["weight"].idxmin()]
    heaviest_cars_1975_1978[year] = cars.loc[cars["weight"].idxmax()]

for year in years_1975_1978:
    print(f'The lightest car from the year {year + 1900} was the {lightest_cars_1975_1978[year]["name"]} with a weight of {lightest_cars_1975_1978[year]["weight"]} lbs')
    print(f'The heaviest car from the year {year + 1900} was the {heaviest_cars_1975_1978[year]["name"]} with a weight of {heaviest_cars_1975_1978[year]["weight"]} lbs')
    print('\n')
# Out:
# The lightest car from the year 1975 was the honda civic cvcc with a weight of 1795 lbs
# The heaviest car from the year 1975 was the pontiac catalina with a weight of 4668 lbs
#
#
# The lightest car from the year 1976 was the honda civic with a weight of 1795 lbs
# The heaviest car from the year 1976 was the cadillac seville with a weight of 4380 lbs
#
#
# The lightest car from the year 1977 was the renault 5 gtl with a weight of 1825 lbs
# The heaviest car from the year 1977 was the ford thunderbird with a weight of 4335 lbs
#
#
# The lightest car from the year 1978 was the ford fiesta with a weight of 1800 lbs
# The heaviest car from the year 1978 was the dodge magnum xe with a weight of 4080 lbs

# %% [markdown]
# #### **Section 2 Analysis**

# %% [markdown]
# **Weight Analysis**
#
# The most characteristic detail about section one is that we find the heaviest and lightest cars in all of the three sections. The heaviest car from section 2 was from the year 1975 being the Pontiac Catalina with a weight of 4668 lbs. For the lightest car we have a peculiarity; We have a tie between the Honda Civic cvcc 1975 and Honda Civic 1976 with same weight of 1795 lbs. The average weight of section 2 is 3022.91 lbs, which is 200 lbs more lighter than the average weight of section 1. We can say that from section 1 to section 2 cars have on average gotten lighter.
#
# 1975 contains the largest outliers, which also makes it have the biggest range. It has a cluster mainly above the main average weight, which tells us that most of the cars build that year were close to the average but significantly heavy.
#
# 1976 has a very denoted division were we can separate the data into three clusters: the bottom cluster, containing the lightest cars, the middle cluster, which mainly lies above the general average, and the top cluster, which contains most of the data points and lies between the 3500lbs to 4300lbs approximately.
#
# 1977 has many denoted gaps in the data set. The main gap is coincidentally around the general average weight, which tells us that this year on average car manufacturers decided either build light cars or heavy cars, almost no in between.
#
# 1978 is the year with the best insights. First, it is the one with less gaps and almost all of the data is really clustered. We can see that most of the points lie below the general average weight and average weight of section 2, something that no other year in section 2 has showed. The heaviest car from this year is the lightest compared to the heaviest of previous years in this section. This year was the one who really helped improve the average weight of section 2 because if it wasn't or this year it would have had a similar average weight to section 1. Most of the data points lay on the lighter side.
#
# **Fuel Efficiency**
#
# The least fuel efficient car from section 2 was the ford mustang ii 1975 with a mpg of 13.0 while the most fuel efficient car from section 2 was the volkswagen rabbit custom diesel 1978 with a mpg of 43.1.The average mpg of section 2 is 22.36 mpg, the exact number from the fuel efficiency of section 1.
#
# It's important to note that this section has one year less. That said, we could infer that the fuel efficiency hasn't improved during this four years even though on average the cars have gotten lighter. But I think that taking the mean as a reference point is deceiving in this case. It's a really strange behavior because if you analyze the pattern it has a positive direction and it seems like it continues the upwards direction that section 1 started.
#
# I infer that the reason why the average didn't improve was because in the year 1978 you can see a big cluster of points that lay below average mpg of section 2. This really divided again the data into almost equal parts which caused the data to average on the middle part of the graph which coincidentally was the average mpg.

# %% [markdown]
# #### **Section 3**

# %%
section_3 = pd.DataFrame(auto_dataset)

filtered_section_3 = section_3.loc[lambda df: (df["year"] >= 79) & (df["year"] <= 82), ["name", "year", "mpg", "weight"]]

print("Section 3 1979-1982:\n", filtered_section_3, "\n")
# Out:
# Section 3 1979-1982:
#                    name  year   mpg  weight
# 280  pontiac lemans v6    79  21.5    3245
# 281   mercury zephyr 6    79  19.8    2990
# 282    ford fairmont 4    79  22.3    2890
# 283   amc concord dl 6    79  20.2    3265
# 284      dodge aspen 6    79  20.6    3360
# ..                 ...   ...   ...     ...
# 392    ford mustang gl    82  27.0    2790
# 393          vw pickup    82  44.0    2130
# 394      dodge rampage    82  32.0    2295
# 395        ford ranger    82  28.0    2625
# 396         chevy s-10    82  31.0    2720
#
# [117 rows x 4 columns]

# %% [markdown]
# #### **Fuel Efficiency Graph Section 3***

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

auto_dataset = pd.read_csv("Auto.csv",
                          na_values=['?'])

section_3 = pd.DataFrame(auto_dataset)

filtered_section_3 = section_3.loc[lambda df: (df["year"] >= 79) & (df["year"] <= 82), ["name", "year", "mpg", "weight"]]

plt.figure(figsize=(12,10))
plt.scatter(filtered_section_3["year"], filtered_section_3["mpg"], color="red", label="Miles per Gallon (mpg)")
plt.xlabel("years")
plt.ylabel("mpg")
plt.title("Fuel Efficiency Of Commercial Cars From 1979-1982")
plt.legend()
plt.show()
